# %% [markdown]
# Lesson 10 - Introduction to Python - Automated Exploratory Data Analysis (EDA) and SQL databases

# %% [markdown]
# ## Automated EDA: Pandas Profiling
#
# Pandas-profiling module is an automated approach to exploratory data analysis.
# Please find the source github repository with all descriptions here: https://github.com/pandas-profiling/pandas-profiling:
#
# "The pandas df.describe() function is great but a little basic for serious exploratory data analysis. pandas_profiling extends the pandas DataFrame with df.profile_report() for quick data analysis.
#
# For each column the following statistics - if relevant for the column type - are presented in an interactive HTML report:
#
# * **Type inference**: detect the types of columns in a dataframe.
# * **Essentials**: type, unique values, missing values
# * **Quantile statistics** like minimum value, Q1, median, Q3, maximum, range, interquartile range
# * **Descriptive statistics** like mean, mode, standard deviation, sum, median absolute deviation, coefficient of variation, kurtosis, skewness
# * **Most frequent values**
# * **Histogram**
# * **Correlations** highlighting of highly correlated variables, Spearman, Pearson and Kendall matrices
# * **Missing values** matrix, count, heatmap and dendrogram of missing values
# * **Text analysis** learn about categories (Uppercase, Space), scripts (Latin, Cyrillic) and blocks (ASCII) of text data.
# * **File and Image** analysis extract file sizes, creation dates and dimensions and scan for truncated images or those containing EXIF information."

# %%
##first install pandas-profiling module
#!pip install pandas-profiling

# %%
#import libraries
import pandas as pd
import numpy as np

#import pandas profiler
from pandas_profiling import ProfileReport

# %% [markdown]
# ### Read college data and data dictionary

# %%
#read data
df = pd.read_csv('data/college.csv')
display(df.head())

#read data dictionary
df_dict = pd.read_csv('data/college_data_dictionary.csv')
display(df_dict)
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]
#            column_name                                        description
# 0               INSTNM                                   Institution Name
# 1                 CITY                                      City Location
# 2               STABBR                                 State Abbreviation
# 3                 HBCU           Historically Black College or University
# 4              MENONLY                                       0/1 Men Only
# 5            WOMENONLY                                     0/1 Women only
# 6             RELAFFIL                          0/1 Religious Affiliation
# 7             SATVRMID                                  SAT Verbal Median
# 8             SATMTMID                                    SAT Math Median
# 9         DISTANCEONLY                            Distance Education Only
# 10                UGDS                           Undergraduate Enrollment
# 11          UGDS_WHITE                            Percent Undergrad White
# 12          UGDS_BLACK                            Percent Undergrad Black
# 13           UGDS_HISP                         Percent Undergrad Hispanic
# 14          UGDS_ASIAN                            Percent Undergrad Asian
# 15           UGDS_AIAN   Percent Undergrad American Indian/Alaskan Native
# 16           UGDS_NHPI  Percent Undergrad Native Hawaiian/Pacific Isla...
# 17           UGDS_2MOR                  Percent Undergrad 2 or more races
# 18            UGDS_NRA              Percent Undergrad non-resident aliens
# 19           UGDS_UNKN                     Percent Undergrad race unknown
# 20            PPTUG_EF                         Percent Students part-time
# 21            CURROPER                            0/1 Currently Operating
# 22             PCTPELL                   Percent Students with Pell grant
# 23            PCTFLOAN                 Percent Students with federal loan
# 24             UG25ABV                     Percent Students Older than 25
# 25     MD_EARN_WNE_P10          Median Earnings 10 years after enrollment
# 26  GRAD_DEBT_MDN_SUPP                          Median debt of completers

# %%
#create a report
profile = ProfileReport(df, title="Pandas Profiling Report")

#display report
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/40 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
#save report to html
profile.to_file("college_report.html")
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Exercise #1
# Build report using pandas-profiling module for movie data stores in data/movie.csv. Save the report in html format. Study the report results and summarize your observations.

# %% [markdown]
# ### Pandas table styling

# %% [markdown]
# Pandas has great functionality for custom styling, see <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html">documentation</a>.
#
# #### Highlight maximum value

# %%
df.select_dtypes(exclude='object').head(10).style.highlight_max(color='green')
# Out:
# <style  type="text/css" >
# #T_e9a1e_row0_col0,#T_e9a1e_row0_col1,#T_e9a1e_row0_col2,#T_e9a1e_row0_col9,#T_e9a1e_row0_col13,#T_e9a1e_row0_col18,#T_e9a1e_row0_col19,#T_e9a1e_row0_col20,#T_e9a1e_row1_col1,#T_e9a1e_row1_col2,#T_e9a1e_row1_col11,#T_e9a1e_row1_col14,#T_e9a1e_row1_col18,#T_e9a1e_row2_col1,#T_e9a1e_row2_col2,#T_e9a1e_row2_col3,#T_e9a1e_row2_col6,#T_e9a1e_row2_col16,#T_e9a1e_row2_col18,#T_e9a1e_row2_col21,#T_e9a1e_row3_col1,#T_e9a1e_row3_col2,#T_e9a1e_row3_col4,#T_e9a1e_row3_col5,#T_e9a1e_row3_col10,#T_e9a1e_row3_col18,#T_e9a1e_row4_col0,#T_e9a1e_row4_col1,#T_e9a1e_row4_col2,#T_e9a1e_row4_col18,#T_e9a1e_row5_col1,#T_e9a1e_row5_col2,#T_e9a1e_row5_col7,#T_e9a1e_row5_col18,#T_e9a1e_row6_col1,#T_e9a1e_row6_col2,#T_e9a1e_row6_col18,#T_e9a1e_row7_col1,#T_e9a1e_row7_col2,#T_e9a1e_row7_col12,#T_e9a1e_row7_col17,#T_e9a1e_row7_col18,#T_e9a1e_row8_col1,#T_e9a1e_row8_col2,#T_e9a1e_row8_col15,#T_e9a1e_row8_col18,#T_e9a1e_row9_col1,#T_e9a1e_row9_col2,#T_e9a1e_row9_col8,#T_e9a1e_row9_col18{
#             background-color:  green;
#         }</style><table id="T_e9a1e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HBCU</th>        <th class="col_heading level0 col1" >MENONLY</th>        <th class="col_heading level0 col2" >WOMENONLY</th>        <th class="col_heading level0 col3" >RELAFFIL</th>        <th class="col_heading level0 col4" >SATVRMID</th>        <th class="col_heading level0 col5" >SATMTMID</th>        <th class="col_heading level0 col6" >DISTANCEONLY</th>        <th class="col_heading level0 col7" >UGDS</th>        <th class="col_heading level0 col8" >UGDS_WHITE</th>        <th class="col_heading level0 col9" >UGDS_BLACK</th>        <th class="col_heading level0 col10" >UGDS_HISP</th>        <th class="col_heading level0 col11" >UGDS_ASIAN</th>        <th class="col_heading level0 col12" >UGDS_AIAN</th>        <th class="col_heading level0 col13" >UGDS_NHPI</th>        <th class="col_heading level0 col14" >UGDS_2MOR</th>        <th class="col_heading level0 col15" >UGDS_NRA</th>        <th class="col_heading level0 col16" >UGDS_UNKN</th>        <th class="col_heading level0 col17" >PPTUG_EF</th>        <th class="col_heading level0 col18" >CURROPER</th>        <th class="col_heading level0 col19" >PCTPELL</th>        <th class="col_heading level0 col20" >PCTFLOAN</th>        <th class="col_heading level0 col21" >UG25ABV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9a1e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e9a1e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e9a1e_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_e9a1e_row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_e9a1e_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_e9a1e_row0_col4" class="data row0 col4" >424.000000</td>
#                         <td id="T_e9a1e_row0_col5" class="data row0 col5" >420.000000</td>
#                         <td id="T_e9a1e_row0_col6" class="data row0 col6" >0.000000</td>
#                         <td id="T_e9a1e_row0_col7" class="data row0 col7" >4206.000000</td>
#                         <td id="T_e9a1e_row0_col8" class="data row0 col8" >0.033300</td>
#                         <td id="T_e9a1e_row0_col9" class="data row0 col9" >0.935300</td>
#                         <td id="T_e9a1e_row0_col10" class="data row0 col10" >0.005500</td>
#                         <td id="T_e9a1e_row0_col11" class="data row0 col11" >0.001900</td>
#                         <td id="T_e9a1e_row0_col12" class="data row0 col12" >0.002400</td>
#                         <td id="T_e9a1e_row0_col13" class="data row0 col13" >0.001900</td>
#                         <td id="T_e9a1e_row0_col14" class="data row0 col14" >0.000000</td>
#                         <td id="T_e9a1e_row0_col15" class="data row0 col15" >0.005900</td>
#                         <td id="T_e9a1e_row0_col16" class="data row0 col16" >0.013800</td>
#                         <td id="T_e9a1e_row0_col17" class="data row0 col17" >0.065600</td>
#                         <td id="T_e9a1e_row0_col18" class="data row0 col18" >1</td>
#                         <td id="T_e9a1e_row0_col19" class="data row0 col19" >0.735600</td>
#                         <td id="T_e9a1e_row0_col20" class="data row0 col20" >0.828400</td>
#                         <td id="T_e9a1e_row0_col21" class="data row0 col21" >0.104900</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a1e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e9a1e_row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_e9a1e_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_e9a1e_row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_e9a1e_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_e9a1e_row1_col4" class="data row1 col4" >570.000000</td>
#                         <td id="T_e9a1e_row1_col5" class="data row1 col5" >565.000000</td>
#                         <td id="T_e9a1e_row1_col6" class="data row1 col6" >0.000000</td>
#                         <td id="T_e9a1e_row1_col7" class="data row1 col7" >11383.000000</td>
#                         <td id="T_e9a1e_row1_col8" class="data row1 col8" >0.592200</td>
#                         <td id="T_e9a1e_row1_col9" class="data row1 col9" >0.260000</td>
#                         <td id="T_e9a1e_row1_col10" class="data row1 col10" >0.028300</td>
#                         <td id="T_e9a1e_row1_col11" class="data row1 col11" >0.051800</td>
#                         <td id="T_e9a1e_row1_col12" class="data row1 col12" >0.002200</td>
#                         <td id="T_e9a1e_row1_col13" class="data row1 col13" >0.000700</td>
#                         <td id="T_e9a1e_row1_col14" class="data row1 col14" >0.036800</td>
#                         <td id="T_e9a1e_row1_col15" class="data row1 col15" >0.017900</td>
#                         <td id="T_e9a1e_row1_col16" class="data row1 col16" >0.010000</td>
#                         <td id="T_e9a1e_row1_col17" class="data row1 col17" >0.260700</td>
#                         <td id="T_e9a1e_row1_col18" class="data row1 col18" >1</td>
#                         <td id="T_e9a1e_row1_col19" class="data row1 col19" >0.346000</td>
#                         <td id="T_e9a1e_row1_col20" class="data row1 col20" >0.521400</td>
#                         <td id="T_e9a1e_row1_col21" class="data row1 col21" >0.242200</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a1e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e9a1e_row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_e9a1e_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_e9a1e_row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_e9a1e_row2_col3" class="data row2 col3" >1</td>
#                         <td id="T_e9a1e_row2_col4" class="data row2 col4" >nan</td>
#                         <td id="T_e9a1e_row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_e9a1e_row2_col6" class="data row2 col6" >1.000000</td>
#                         <td id="T_e9a1e_row2_col7" class="data row2 col7" >291.000000</td>
#                         <td id="T_e9a1e_row2_col8" class="data row2 col8" >0.299000</td>
#                         <td id="T_e9a1e_row2_col9" class="data row2 col9" >0.419200</td>
#                         <td id="T_e9a1e_row2_col10" class="data row2 col10" >0.006900</td>
#                         <td id="T_e9a1e_row2_col11" class="data row2 col11" >0.003400</td>
#                         <td id="T_e9a1e_row2_col12" class="data row2 col12" >0.000000</td>
#                         <td id="T_e9a1e_row2_col13" class="data row2 col13" >0.00000

# %% [markdown]
# #### Highlight both maximum and minimum values

# %%
df.select_dtypes(exclude='object').head(10).style.highlight_max(color='green').highlight_min(color='red')
# Out:
# <style  type="text/css" >
# #T_e7a78_row0_col0,#T_e7a78_row0_col9,#T_e7a78_row0_col13,#T_e7a78_row0_col19,#T_e7a78_row0_col20,#T_e7a78_row1_col11,#T_e7a78_row1_col14,#T_e7a78_row2_col3,#T_e7a78_row2_col6,#T_e7a78_row2_col16,#T_e7a78_row2_col21,#T_e7a78_row3_col4,#T_e7a78_row3_col5,#T_e7a78_row3_col10,#T_e7a78_row4_col0,#T_e7a78_row5_col7,#T_e7a78_row7_col12,#T_e7a78_row7_col17,#T_e7a78_row8_col15,#T_e7a78_row9_col8{
#             background-color:  green;
#         }#T_e7a78_row0_col1,#T_e7a78_row0_col2,#T_e7a78_row0_col18,#T_e7a78_row1_col1,#T_e7a78_row1_col2,#T_e7a78_row1_col18,#T_e7a78_row2_col1,#T_e7a78_row2_col2,#T_e7a78_row2_col18,#T_e7a78_row3_col1,#T_e7a78_row3_col2,#T_e7a78_row3_col18,#T_e7a78_row4_col1,#T_e7a78_row4_col2,#T_e7a78_row4_col18,#T_e7a78_row5_col1,#T_e7a78_row5_col2,#T_e7a78_row5_col18,#T_e7a78_row6_col1,#T_e7a78_row6_col2,#T_e7a78_row6_col18,#T_e7a78_row7_col1,#T_e7a78_row7_col2,#T_e7a78_row7_col18,#T_e7a78_row8_col1,#T_e7a78_row8_col2,#T_e7a78_row8_col18,#T_e7a78_row9_col1,#T_e7a78_row9_col2,#T_e7a78_row9_col18{
#             background-color:  green;
#             background-color:  red;
#         }#T_e7a78_row0_col3,#T_e7a78_row0_col4,#T_e7a78_row0_col5,#T_e7a78_row0_col6,#T_e7a78_row0_col11,#T_e7a78_row0_col14,#T_e7a78_row0_col17,#T_e7a78_row1_col0,#T_e7a78_row1_col3,#T_e7a78_row1_col6,#T_e7a78_row2_col0,#T_e7a78_row2_col7,#T_e7a78_row2_col12,#T_e7a78_row2_col13,#T_e7a78_row2_col14,#T_e7a78_row2_col15,#T_e7a78_row3_col0,#T_e7a78_row3_col3,#T_e7a78_row3_col6,#T_e7a78_row4_col3,#T_e7a78_row4_col6,#T_e7a78_row4_col8,#T_e7a78_row4_col11,#T_e7a78_row5_col0,#T_e7a78_row5_col3,#T_e7a78_row5_col6,#T_e7a78_row6_col0,#T_e7a78_row6_col3,#T_e7a78_row6_col6,#T_e7a78_row6_col10,#T_e7a78_row6_col13,#T_e7a78_row6_col14,#T_e7a78_row6_col15,#T_e7a78_row6_col16,#T_e7a78_row7_col0,#T_e7a78_row7_col3,#T_e7a78_row7_col6,#T_e7a78_row8_col0,#T_e7a78_row8_col3,#T_e7a78_row8_col6,#T_e7a78_row9_col0,#T_e7a78_row9_col3,#T_e7a78_row9_col6,#T_e7a78_row9_col9,#T_e7a78_row9_col13,#T_e7a78_row9_col14,#T_e7a78_row9_col19,#T_e7a78_row9_col20,#T_e7a78_row9_col21{
#             background-color:  red;
#         }</style><table id="T_e7a78_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HBCU</th>        <th class="col_heading level0 col1" >MENONLY</th>        <th class="col_heading level0 col2" >WOMENONLY</th>        <th class="col_heading level0 col3" >RELAFFIL</th>        <th class="col_heading level0 col4" >SATVRMID</th>        <th class="col_heading level0 col5" >SATMTMID</th>        <th class="col_heading level0 col6" >DISTANCEONLY</th>        <th class="col_heading level0 col7" >UGDS</th>        <th class="col_heading level0 col8" >UGDS_WHITE</th>        <th class="col_heading level0 col9" >UGDS_BLACK</th>        <th class="col_heading level0 col10" >UGDS_HISP</th>        <th class="col_heading level0 col11" >UGDS_ASIAN</th>        <th class="col_heading level0 col12" >UGDS_AIAN</th>        <th class="col_heading level0 col13" >UGDS_NHPI</th>        <th class="col_heading level0 col14" >UGDS_2MOR</th>        <th class="col_heading level0 col15" >UGDS_NRA</th>        <th class="col_heading level0 col16" >UGDS_UNKN</th>        <th class="col_heading level0 col17" >PPTUG_EF</th>        <th class="col_heading level0 col18" >CURROPER</th>        <th class="col_heading level0 col19" >PCTPELL</th>        <th class="col_heading level0 col20" >PCTFLOAN</th>        <th class="col_heading level0 col21" >UG25ABV</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7a78_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7a78_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e7a78_row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_e7a78_row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_e7a78_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_e7a78_row0_col4" class="data row0 col4" >424.000000</td>
#                         <td id="T_e7a78_row0_col5" class="data row0 col5" >420.000000</td>
#                         <td id="T_e7a78_row0_col6" class="data row0 col6" >0.000000</td>
#                         <td id="T_e7a78_row0_col7" class="data row0 col7" >4206.000000</td>
#                         <td id="T_e7a78_row0_col8" class="data row0 col8" >0.033300</td>
#                         <td id="T_e7a78_row0_col9" class="data row0 col9" >0.935300</td>
#                         <td id="T_e7a78_row0_col10" class="data row0 col10" >0.005500</td>
#                         <td id="T_e7a78_row0_col11" class="data row0 col11" >0.001900</td>
#                         <td id="T_e7a78_row0_col12" class="data row0 col12" >0.002400</td>
#                         <td id="T_e7a78_row0_col13" class="data row0 col13" >0.001900</td>
#                         <td id="T_e7a78_row0_col14" class="data row0 col14" >0.000000</td>
#                         <td id="T_e7a78_row0_col15" class="data row0 col15" >0.005900</td>
#                         <td id="T_e7a78_row0_col16" class="data row0 col16" >0.013800</td>
#                         <td id="T_e7a78_row0_col17" class="data row0 col17" >0.065600</td>
#                         <td id="T_e7a78_row0_col18" class="data row0 col18" >1</td>
#                         <td id="T_e7a78_row0_col19" class="data row0 col19" >0.735600</td>
#                         <td id="T_e7a78_row0_col20" class="data row0 col20" >0.828400</td>
#                         <td id="T_e7a78_row0_col21" class="data row0 col21" >0.104900</td>
#             </tr>
#             <tr>
#                         <th id="T_e7a78_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e7a78_row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_e7a78_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_e7a78_row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_e7a78_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_e7a78_row1_col4" class="data row1 col4" >570.000000</td>
#                         <td id="T_e7a78_row1_col5" class="data row1 col5" >565.000000</td>
#                         <td id="T_e7a78_row1_col6" class="data row1 col6" >0.000000</td>
#                         <td id="T_e7a78_row1_col7" class="data row1 col7" >11383.000000</td>
#                         <td id="T_e7a78_row1_col8" class="data row1 col8" >0.592200</td>
#                         <td id="T_e7a78_row1_col9" class="data row1 col9" >0.260000</td>
#                         <td id="T_e7a78_row1_col10" class="data row1 col10" >0.028300</td>
#                         <td id="T_e7a78_row1_col11" class="data row1 col11" >0.051800</td>
#                         <td id="T_e7a78_row1_col12" class="data row1 col12" >0.002200</td>
#                         <td id="T_e7a78_row1_col13" class="data row1 col13" >0.000700</td>
#                         <td id="T_e7a78_row1_col14" class="data row1 col14" >0.036800</td>
#                         <td id="T_e7a78_row1_col15" class="data row1 col15" >0.017900</td>
#                         <td id="T_e7a78_row1_col16" class="data row1 col16" >0.010000</td>
#                         <td id="T_e7a78_row1_col17" class="data row1 col17" >0.260700</td>
#                         <td id="T_e7a78_row1_col18" class="data row1 col18" >1</td>
#                         <td id="T_e7a78_row1_col19" class="data row1 col19" >0.346000</td>
#                         <td id="T_e7a78_row1_col20" class="data row1 col20" >0.521400</td>
#                         <td id="T_e7a78_row1_col21" class="data row1 col21" >0.242200</td>
#             </tr>
#             <tr>
#                         <th id="T_e7a78_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e7a78_row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_e7a78_row2_col1" class="data r

# %% [markdown]
# #### Apply specific mapping for the data

# %%
#find most frequent
def highlight_top5(s):
    '''
    highlight the top 10 in a Series yellow.
    '''
    top5 = s.value_counts()[:5].index
    
    is_top5 = s.isin(top5)
    return ['background-color: yellow' if v else 'background-color: grey' for v in is_top5]

# %%
df.sample(10).select_dtypes(include='object').style.apply(highlight_top5)
# Out:
# <style  type="text/css" >
# #T_b8479_row0_col0,#T_b8479_row0_col1,#T_b8479_row0_col2,#T_b8479_row0_col4,#T_b8479_row1_col0,#T_b8479_row1_col2,#T_b8479_row1_col4,#T_b8479_row2_col0,#T_b8479_row2_col2,#T_b8479_row2_col3,#T_b8479_row2_col4,#T_b8479_row3_col0,#T_b8479_row4_col1,#T_b8479_row4_col3,#T_b8479_row5_col1,#T_b8479_row5_col3,#T_b8479_row5_col4,#T_b8479_row6_col0,#T_b8479_row6_col2,#T_b8479_row7_col2,#T_b8479_row7_col4,#T_b8479_row8_col1,#T_b8479_row8_col2,#T_b8479_row8_col3,#T_b8479_row9_col1,#T_b8479_row9_col2,#T_b8479_row9_col3,#T_b8479_row9_col4{
#             background-color:  yellow;
#         }#T_b8479_row0_col3,#T_b8479_row1_col1,#T_b8479_row1_col3,#T_b8479_row2_col1,#T_b8479_row3_col1,#T_b8479_row3_col2,#T_b8479_row3_col3,#T_b8479_row3_col4,#T_b8479_row4_col0,#T_b8479_row4_col2,#T_b8479_row4_col4,#T_b8479_row5_col0,#T_b8479_row5_col2,#T_b8479_row6_col1,#T_b8479_row6_col3,#T_b8479_row6_col4,#T_b8479_row7_col0,#T_b8479_row7_col1,#T_b8479_row7_col3,#T_b8479_row8_col0,#T_b8479_row8_col4,#T_b8479_row9_col0{
#             background-color:  grey;
#         }</style><table id="T_b8479_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >INSTNM</th>        <th class="col_heading level0 col1" >CITY</th>        <th class="col_heading level0 col2" >STABBR</th>        <th class="col_heading level0 col3" >MD_EARN_WNE_P10</th>        <th class="col_heading level0 col4" >GRAD_DEBT_MDN_SUPP</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8479_level0_row0" class="row_heading level0 row0" >1760</th>
#                         <td id="T_b8479_row0_col0" class="data row0 col0" >Aquinas College</td>
#                         <td id="T_b8479_row0_col1" class="data row0 col1" >Grand Rapids</td>
#                         <td id="T_b8479_row0_col2" class="data row0 col2" >MI</td>
#                         <td id="T_b8479_row0_col3" class="data row0 col3" >35800</td>
#                         <td id="T_b8479_row0_col4" class="data row0 col4" >25000</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row1" class="row_heading level0 row1" >2178</th>
#                         <td id="T_b8479_row1_col0" class="data row1 col0" >Great Basin College</td>
#                         <td id="T_b8479_row1_col1" class="data row1 col1" >Elko</td>
#                         <td id="T_b8479_row1_col2" class="data row1 col2" >NV</td>
#                         <td id="T_b8479_row1_col3" class="data row1 col3" >30900</td>
#                         <td id="T_b8479_row1_col4" class="data row1 col4" >12735.5</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row2" class="row_heading level0 row2" >1470</th>
#                         <td id="T_b8479_row2_col0" class="data row2 col0" >Centenary College of Louisiana</td>
#                         <td id="T_b8479_row2_col1" class="data row2 col1" >Shreveport</td>
#                         <td id="T_b8479_row2_col2" class="data row2 col2" >LA</td>
#                         <td id="T_b8479_row2_col3" class="data row2 col3" >40400</td>
#                         <td id="T_b8479_row2_col4" class="data row2 col4" >25000</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row3" class="row_heading level0 row3" >1386</th>
#                         <td id="T_b8479_row3_col0" class="data row3 col0" >Wichita Area Technical College</td>
#                         <td id="T_b8479_row3_col1" class="data row3 col1" >Wichita</td>
#                         <td id="T_b8479_row3_col2" class="data row3 col2" >KS</td>
#                         <td id="T_b8479_row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_b8479_row3_col4" class="data row3 col4" >9451</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row4" class="row_heading level0 row4" >3460</th>
#                         <td id="T_b8479_row4_col0" class="data row4 col0" >University of South Carolina-Salkehatchie</td>
#                         <td id="T_b8479_row4_col1" class="data row4 col1" >Allendale</td>
#                         <td id="T_b8479_row4_col2" class="data row4 col2" >SC</td>
#                         <td id="T_b8479_row4_col3" class="data row4 col3" >25200</td>
#                         <td id="T_b8479_row4_col4" class="data row4 col4" >12000</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row5" class="row_heading level0 row5" >3214</th>
#                         <td id="T_b8479_row5_col0" class="data row5 col0" >Aria Health School of Nursing</td>
#                         <td id="T_b8479_row5_col1" class="data row5 col1" >Trevose</td>
#                         <td id="T_b8479_row5_col2" class="data row5 col2" >PA</td>
#                         <td id="T_b8479_row5_col3" class="data row5 col3" >62400</td>
#                         <td id="T_b8479_row5_col4" class="data row5 col4" >26871</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row6" class="row_heading level0 row6" >7122</th>
#                         <td id="T_b8479_row6_col0" class="data row6 col0" >University of Phoenix-Louisiana</td>
#                         <td id="T_b8479_row6_col1" class="data row6 col1" >Baton Rouge</td>
#                         <td id="T_b8479_row6_col2" class="data row6 col2" >LA</td>
#                         <td id="T_b8479_row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_b8479_row6_col4" class="data row6 col4" >33000</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row7" class="row_heading level0 row7" >7092</th>
#                         <td id="T_b8479_row7_col0" class="data row7 col0" >Excel Academies of Cosmetology</td>
#                         <td id="T_b8479_row7_col1" class="data row7 col1" >Lansing</td>
#                         <td id="T_b8479_row7_col2" class="data row7 col2" >MI</td>
#                         <td id="T_b8479_row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_b8479_row7_col4" class="data row7 col4" >PrivacySuppressed</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row8" class="row_heading level0 row8" >2106</th>
#                         <td id="T_b8479_row8_col0" class="data row8 col0" >William Jewell College</td>
#                         <td id="T_b8479_row8_col1" class="data row8 col1" >Liberty</td>
#                         <td id="T_b8479_row8_col2" class="data row8 col2" >MO</td>
#                         <td id="T_b8479_row8_col3" class="data row8 col3" >42300</td>
#                         <td id="T_b8479_row8_col4" class="data row8 col4" >26625</td>
#             </tr>
#             <tr>
#                         <th id="T_b8479_level0_row9" class="row_heading level0 row9" >3685</th>
#                         <td id="T_b8479_row9_col0" class="data row9 col0" >Lamar State College-Orange</td>
#                         <td id="T_b8479_row9_col1" class="data row9 col1" >Orange</td>
#                         <td id="T_b8479_row9_col2" class="data row9 col2" >TX</td>
#                         <td id="T_b8479_row9_col3" class="data row9 col3" >27300</td>
#                         <td id="T_b8479_row9_col4" class="data row9 col4" >10212.5</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Bar plot on top of data table

# %%
#calculate zscore for SAT Math Median column
df['SATMTMID_ZSCORE'] = (df['SATMTMID'] - df['SATMTMID'].mean())/df['SATMTMID'].std()

#select specific columns to show
use_cols = ['INSTNM','SATMTMID','SATMTMID_ZSCORE']

#apply style with bar plot showing negative values in red and positive in grees
df[use_cols].head(10).style.bar(subset=['SATMTMID_ZSCORE'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_0b3c3_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
#         }#T_0b3c3_row1_col2,#T_0b3c3_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 85.3%, transparent 85.3%);
#         }#T_0b3c3_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 100.0%, transparent 100.0%);
#         }#T_0b3c3_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, #d65f5f 5.9%, #d65f5f 65.2%, transparent 65.2%);
#         }#T_0b3c3_row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 52.4%, #d65f5f 52.4%, #d65f5f 65.2%, transparent 65.2%);
#         }#T_0b3c3_row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 98.8%, transparent 98.8%);
#         }</style><table id="T_0b3c3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >INSTNM</th>        <th class="col_heading level0 col1" >SATMTMID</th>        <th class="col_heading level0 col2" >SATMTMID_ZSCORE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b3c3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b3c3_row0_col0" class="data row0 col0" >Alabama A & M University</td>
#                         <td id="T_0b3c3_row0_col1" class="data row0 col1" >420.000000</td>
#                         <td id="T_0b3c3_row0_col2" class="data row0 col2" >-1.507628</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0b3c3_row1_col0" class="data row1 col0" >University of Alabama at Birmingham</td>
#                         <td id="T_0b3c3_row1_col1" class="data row1 col1" >565.000000</td>
#                         <td id="T_0b3c3_row1_col2" class="data row1 col2" >0.465973</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0b3c3_row2_col0" class="data row2 col0" >Amridge University</td>
#                         <td id="T_0b3c3_row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_0b3c3_row2_col2" class="data row2 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0b3c3_row3_col0" class="data row3 col0" >University of Alabama in Huntsville</td>
#                         <td id="T_0b3c3_row3_col1" class="data row3 col1" >590.000000</td>
#                         <td id="T_0b3c3_row3_col2" class="data row3 col2" >0.806249</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0b3c3_row4_col0" class="data row4 col0" >Alabama State University</td>
#                         <td id="T_0b3c3_row4_col1" class="data row4 col1" >430.000000</td>
#                         <td id="T_0b3c3_row4_col2" class="data row4 col2" >-1.371517</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0b3c3_row5_col0" class="data row5 col0" >The University of Alabama</td>
#                         <td id="T_0b3c3_row5_col1" class="data row5 col1" >565.000000</td>
#                         <td id="T_0b3c3_row5_col2" class="data row5 col2" >0.465973</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0b3c3_row6_col0" class="data row6 col0" >Central Alabama Community College</td>
#                         <td id="T_0b3c3_row6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_0b3c3_row6_col2" class="data row6 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0b3c3_row7_col0" class="data row7 col0" >Athens State University</td>
#                         <td id="T_0b3c3_row7_col1" class="data row7 col1" >nan</td>
#                         <td id="T_0b3c3_row7_col2" class="data row7 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0b3c3_row8_col0" class="data row8 col0" >Auburn University at Montgomery</td>
#                         <td id="T_0b3c3_row8_col1" class="data row8 col1" >509.000000</td>
#                         <td id="T_0b3c3_row8_col2" class="data row8 col2" >-0.296245</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3c3_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0b3c3_row9_col0" class="data row9 col0" >Auburn University</td>
#                         <td id="T_0b3c3_row9_col1" class="data row9 col1" >588.000000</td>
#                         <td id="T_0b3c3_row9_col2" class="data row9 col2" >0.779027</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Apply format to the table for display

# %%
#define format dictionary specifying format for each column
format_dict = {'SATMTMID': "{:.0f}", 'SATMTMID_ZSCORE': "{:.3f}"}

#replace nan with '-' and hide index
df[use_cols].head(10).style.format(format_dict, na_rep="-").hide_index()\
            .bar(subset=['SATMTMID_ZSCORE'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_05c88_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.2%, transparent 65.2%);
#         }#T_05c88_row1_col2,#T_05c88_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 85.3%, transparent 85.3%);
#         }#T_05c88_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 100.0%, transparent 100.0%);
#         }#T_05c88_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, #d65f5f 5.9%, #d65f5f 65.2%, transparent 65.2%);
#         }#T_05c88_row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 52.4%, #d65f5f 52.4%, #d65f5f 65.2%, transparent 65.2%);
#         }#T_05c88_row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 65.2%, #5fba7d 65.2%, #5fba7d 98.8%, transparent 98.8%);
#         }</style><table id="T_05c88_" ><thead>    <tr>        <th class="col_heading level0 col0" >INSTNM</th>        <th class="col_heading level0 col1" >SATMTMID</th>        <th class="col_heading level0 col2" >SATMTMID_ZSCORE</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_05c88_row0_col0" class="data row0 col0" >Alabama A & M University</td>
#                         <td id="T_05c88_row0_col1" class="data row0 col1" >420</td>
#                         <td id="T_05c88_row0_col2" class="data row0 col2" >-1.508</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row1_col0" class="data row1 col0" >University of Alabama at Birmingham</td>
#                         <td id="T_05c88_row1_col1" class="data row1 col1" >565</td>
#                         <td id="T_05c88_row1_col2" class="data row1 col2" >0.466</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row2_col0" class="data row2 col0" >Amridge University</td>
#                         <td id="T_05c88_row2_col1" class="data row2 col1" >-</td>
#                         <td id="T_05c88_row2_col2" class="data row2 col2" >-</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row3_col0" class="data row3 col0" >University of Alabama in Huntsville</td>
#                         <td id="T_05c88_row3_col1" class="data row3 col1" >590</td>
#                         <td id="T_05c88_row3_col2" class="data row3 col2" >0.806</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row4_col0" class="data row4 col0" >Alabama State University</td>
#                         <td id="T_05c88_row4_col1" class="data row4 col1" >430</td>
#                         <td id="T_05c88_row4_col2" class="data row4 col2" >-1.372</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row5_col0" class="data row5 col0" >The University of Alabama</td>
#                         <td id="T_05c88_row5_col1" class="data row5 col1" >565</td>
#                         <td id="T_05c88_row5_col2" class="data row5 col2" >0.466</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row6_col0" class="data row6 col0" >Central Alabama Community College</td>
#                         <td id="T_05c88_row6_col1" class="data row6 col1" >-</td>
#                         <td id="T_05c88_row6_col2" class="data row6 col2" >-</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row7_col0" class="data row7 col0" >Athens State University</td>
#                         <td id="T_05c88_row7_col1" class="data row7 col1" >-</td>
#                         <td id="T_05c88_row7_col2" class="data row7 col2" >-</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row8_col0" class="data row8 col0" >Auburn University at Montgomery</td>
#                         <td id="T_05c88_row8_col1" class="data row8 col1" >509</td>
#                         <td id="T_05c88_row8_col2" class="data row8 col2" >-0.296</td>
#             </tr>
#             <tr>
#                                 <td id="T_05c88_row9_col0" class="data row9 col0" >Auburn University</td>
#                         <td id="T_05c88_row9_col1" class="data row9 col1" >588</td>
#                         <td id="T_05c88_row9_col2" class="data row9 col2" >0.779</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Data manipulation with `assign`,  `apply` and `map` methods

# %% [markdown]
# To add new columns that are computed from other available features `assign` method can be used, see <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html">documentation</a>.

# %%
df.assign(SATVRMID_ZSCORE = (df['SATVRMID'] - df['SATVRMID'].mean())/df['SATVRMID'].std())\
                            [['SATVRMID','SATVRMID_ZSCORE']].head()
# Out:
#    SATVRMID  SATVRMID_ZSCORE
# 0     424.0        -1.440960
# 1     570.0         0.687976
# 2       NaN              NaN
# 3     595.0         1.052520
# 4     425.0        -1.426378

# %% [markdown]
# To do some calculations or transformations on available features `apply` method can be used, see <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html">documentation</a>.

# %%
df[['CITY','STABBR']].apply(tuple, axis=1).head()
# Out:
# 0        (Normal, AL)
# 1    (Birmingham, AL)
# 2    (Montgomery, AL)
# 3    (Huntsville, AL)
# 4    (Montgomery, AL)
# dtype: object

# %%
from scipy.stats import zscore

df[['SATVRMID_ZSCORE']] = df[['SATVRMID']].apply(zscore, nan_policy = 'omit')

df[['SATVRMID', 'SATVRMID_ZSCORE']].head(5)
# Out:
#    SATVRMID  SATVRMID_ZSCORE
# 0     424.0        -1.441569
# 1     570.0         0.688266
# 2       NaN              NaN
# 3     595.0         1.052964
# 4     425.0        -1.426981

# %% [markdown]
# In order to convert column values accorting some mappring rules dictionary with rules can be passed to `map` method as below. Application: in order to save memory may need to store feature having string type values to integer code.

# %%
states = df['STABBR'].unique()
states_code = np.arange(1, len(states)+1)

state_dict = dict(zip(states, states_code))
#state_dict

# %%
df['STABBR_CODE'] = df['STABBR'].map(state_dict)

df[['STABBR', 'STABBR_CODE']].sample(10)
# Out:
#      STABBR  STABBR_CODE
# 2838     OH           38
# 3579     TN           20
# 2551     NY           11
# 3231     PA           42
# 3332     PA           42
# 4867     CA            7
# 866      GA           16
# 286      CA            7
# 2574     NY           11
# 2415     NY           11

# %% [markdown]
# ### Lambda function
#
# A lambda function is a small anonymous function. A lambda function can take any number of arguments, but can only have one expression.
#
# Lambda expressions (or lambda functions) are essentially blocks of code that can be assigned to variables, passed as an argument, or returned from a function call, in languages that support high-order functions. They have been part of programming languages for quite some time.
#
# Lambda functions are obvious choice to pandas data transformation, e.g. using apply method.

# %%
# a lambda function that adds 10 to the number passed in as an argument, and prints the result:

x = lambda a : a + 10

x(5)
# Out:
# 15

# %%
# a lambda function that multiplies argument a with argument b and print the result:
# def x(a,b):
#     return a*b

x = lambda a, b, c : a * b + c

x(5, 6, 7)
# Out:
# 37

# %%
df.assign(SATVRMID_ZSCORE = lambda x: (x['SATVRMID'] 
                                       - x['SATVRMID'].mean())
                                       /x['SATVRMID'].std())\
  [['SATVRMID', 'SATVRMID_ZSCORE']].head(5)
# Out:
#    SATVRMID  SATVRMID_ZSCORE
# 0     424.0        -1.440960
# 1     570.0         0.687976
# 2       NaN              NaN
# 3     595.0         1.052520
# 4     425.0        -1.426378

# %% [markdown]
# # Data Engineering

# %% [markdown]
# ## Create a SQL database using `sqlite3` libruary

# %% [markdown]
# To create sql database using macOS run in terminal:
#
# "sqlite3 college.db"

# %% [markdown]
# We will use the `sqlite3` module ([documentation here](https://docs.python.org/3/library/sqlite3.html)). We start by opening a *connection* to the database with `sqlite3.connect`:

# %%
import sqlite3 

#establish conection
conn = sqlite3.connect('college.db')
#set cursor
cur = conn.cursor()

# %%
ls
# Out:
# Jupyter Notebook Introduction - AIA Global's Introduction to Python.ipynb
# Lesson 1 - AIA Global's Introduction to Python.ipynb
# Lesson 2 - AIA Global's Introduction to Python.ipynb
# Lesson 2 - Solutions.ipynb
# Lesson 3 - AIA Global's Introduction to Python.ipynb
# Lesson 3 - Solutions.ipynb
# Lesson 4 - AIA Global's Introduction to Python.ipynb
# Lesson 4 - Solutions.ipynb
# Lesson 5 - AIA Global's Introduction to Python.ipynb
# Lesson 5 - Solutions.ipynb
# Lesson 6 - AIA Global's Introduction to Python.ipynb
# Lesson 7 - AIA Global's Introduction to Python.ipynb
# Lesson 8 - AIA Global's Introduction to Python.ipynb
# Lesson 9 - AIA Global's Introduction to Python.ipynb
# Python Installation Instructions for Upcoming Course - AIA Introduction to Python.pdf
# __pycache__/
# college.db
# college_report.html
# data/
# images/
# module.py
# movie_report.html
# pandas.png
# python.jpeg
# stock_smoother.py

# %%
#install sqlalchemy libruary
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.7/site-packages (1.3.21)

# %% [markdown]
# ### Delete table

# %%
#to delete table
cur.execute("""DROP TABLE college_select;""")

# %% [markdown]
# ### Create table

# %%
#Creating the cats table
cur.execute("""CREATE TABLE college_select (
                                            id INTEGER PRIMARY KEY,
                                            INSTNM TEXT,
                                            STABBR TEXT,
                                            SATVRMID REAL,
                                            SATMTMID REAL,
                                            UGDS REAL);          
            """)

# %%
#make a tuple and fill nan with 0
series_of_tuples = df[['INSTNM', 'STABBR', 'SATVRMID', 'SATMTMID', 'UGDS']]\
                     .fillna(0).apply(tuple, axis=1)

for index, value in series_of_tuples.iteritems():

    cur.execute(f'''INSERT INTO college_select (INSTNM, STABBR, SATVRMID, SATMTMID, UGDS) 
                    VALUES {value};
                 ''')

# %%
#Commit your changes in the database
conn.commit()

#closing the connection
conn.close()

# %% [markdown]
# ## Connect to a SQL database

# %%
import sqlite3 

#Connecting to sqlite
conn = sqlite3.connect('college.db')

#Creating a cursor object using the cursor() method
cur = conn.cursor()

# Execute the query
cur.execute("""SELECT name FROM sqlite_master WHERE type = 'table';""")
# Fetch the result and store it in table_names
table_names = cur.fetchall()
table_names
# Out:
# [('college_select',)]

# %%
cur.execute("""SELECT * FROM college_select LIMIT 5;""")
cur.fetchall()
# Out:
# [(1, 'Alabama A & M University', 'AL', 424.0, 420.0, 4206.0),
#  (2, 'University of Alabama at Birmingham', 'AL', 570.0, 565.0, 11383.0),
#  (3, 'Amridge University', 'AL', 0.0, 0.0, 291.0),
#  (4, 'University of Alabama in Huntsville', 'AL', 595.0, 590.0, 5451.0),
#  (5, 'Alabama State University', 'AL', 425.0, 430.0, 4811.0)]

# %% [markdown]
# ### Exercise #2
# Create SQL table college_data_dictionary and add df_dict data there.

# %%
# your code

# %% [markdown]
# ## Saving Results into Pandas DataFrames
# It is more convenient to turn these results into pandas DataFrames. One way to do this would be to wrap the `c.fetchall()` output with a pandas DataFrame constructor:

# %%
query = """
            SELECT *
            FROM college_select;
        """

df_sql = pd.DataFrame(cur.execute(query).fetchall())

df_sql.head()
# Out:
#    0                                    1   2      3      4        5
# 0  1             Alabama A & M University  AL  424.0  420.0   4206.0
# 1  2  University of Alabama at Birmingham  AL  570.0  565.0  11383.0
# 2  3                   Amridge University  AL    0.0    0.0    291.0
# 3  4  University of Alabama in Huntsville  AL  595.0  590.0   5451.0
# 4  5             Alabama State University  AL  425.0  430.0   4811.0

# %% [markdown]
# However there are no column. We can access the column names by calling `cur.description`:

# %%
cur.description
# Out:
# (('id', None, None, None, None, None, None),
#  ('INSTNM', None, None, None, None, None, None),
#  ('STABBR', None, None, None, None, None, None),
#  ('SATVRMID', None, None, None, None, None, None),
#  ('SATMTMID', None, None, None, None, None, None),
#  ('UGDS', None, None, None, None, None, None))

# %%
#reassign column:
df_sql.columns = [x[0] for x in cur.description]
df_sql.head()
# Out:
#    id                               INSTNM STABBR  SATVRMID  SATMTMID     UGDS
# 0   1             Alabama A & M University     AL     424.0     420.0   4206.0
# 1   2  University of Alabama at Birmingham     AL     570.0     565.0  11383.0
# 2   3                   Amridge University     AL       0.0       0.0    291.0
# 3   4  University of Alabama in Huntsville     AL     595.0     590.0   5451.0
# 4   5             Alabama State University     AL     425.0     430.0   4811.0

# %% [markdown]
# Another better way to do it is by usign pandas method directly designed for reading from SQL databases ([documentation here](https://pandas.pydata.org/docs/reference/api/pandas.read_sql.html)). Instead of using the cursor, all you need is the connection variable:

# %%
df_sql = pd.read_sql(query, conn)
df_sql.head()
# Out:
#    id                               INSTNM STABBR  SATVRMID  SATMTMID     UGDS
# 0   1             Alabama A & M University     AL     424.0     420.0   4206.0
# 1   2  University of Alabama at Birmingham     AL     570.0     565.0  11383.0
# 2   3                   Amridge University     AL       0.0       0.0    291.0
# 3   4  University of Alabama in Huntsville     AL     595.0     590.0   5451.0
# 4   5             Alabama State University     AL     425.0     430.0   4811.0

# %%
#pass any query
pd.read_sql("""SELECT INSTNM, UGDS 
               FROM college_select
               LIMIT 3;""", conn)
# Out:
#                                 INSTNM     UGDS
# 0             Alabama A & M University   4206.0
# 1  University of Alabama at Birmingham  11383.0
# 2                   Amridge University    291.0

# %% [markdown]
# ### Grouping by state and aggregate by Count

# %%
q = """
SELECT STABBR, COUNT(*)
FROM college_select
GROUP BY STABBR
;
"""
# Displaying just the first 10 countries for readability
pd.read_sql(q, conn).head(10)
# Out:
#   STABBR  COUNT(*)
# 0     AK        10
# 1     AL        96
# 2     AR        86
# 3     AS         1
# 4     AZ       133
# 5     CA       773
# 6     CO       125
# 7     CT       102
# 8     DC        26
# 9     DE        19

# %% [markdown]
# ### The same operation using pandas dataframe

# %%
df_sql.groupby(['STABBR'])[['STABBR']].count().head(10)\
      .rename(columns={'STABBR':'COUNT(*)'}).reset_index()
# Out:
#   STABBR  COUNT(*)
# 0     AK        10
# 1     AL        96
# 2     AR        86
# 3     AS         1
# 4     AZ       133
# 5     CA       773
# 6     CO       125
# 7     CT       102
# 8     DC        26
# 9     DE        19

# %%
#closing the connection
conn.close()

# %% [markdown]
# ### Exercise #3
# Execute custom sql query on college_select table using pd.read_sql() method. For example find mean value of undergraduate enrollment (UGDS) per state (STABBR).

# %%
#your code
