# %% [markdown]
# ## Import Libraries

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ## Data Filepaths

# %%
# You can customize your data locations here:

sp500_all_financials = './data/sp500_all_financials.csv'
sp500_companies = './data/sp500_companies.csv'
sp_500_income_statements = './data/sp500_income_statements.csv'
sp_500_balance_sheets = './data/sp500_balance_sheets.csv'
sp_500_cash_flows = './data/sp500_cash_flows.csv'
sp_500_financials = './data/sp500_financials.xlsx'

# %% [markdown]
# ## Fetch List of S&P Ticker Symbols

# %%
# Fetch the S&P 500 list from Wikipedia

sp_500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp_500_companies = pd.read_html(sp_500_url)[0]

# %% [markdown]
# ## Extract and Transform S&P 500 Data

# %%
# Obtain a list of all the S&P 500 ticker symbols 
tickers = sp_500_companies['Symbol'].tolist()

# Function to rearrange columns: Move 'Symbol' column to the front
def move_symbol_to_front(df):
    if 'Symbol' in df.columns:
        cols = ['Symbol'] + [col for col in df.columns if col != 'Symbol']
        return df[cols]
    return df

# Initialize empty DataFrames to store individual financial statements if needed
income_statements = pd.DataFrame()
balance_sheets = pd.DataFrame()
cash_flows = pd.DataFrame()
all_financials = pd.DataFrame()

# Iterate over each ticker symbol
for tick in tickers:
    try:
        # Fetch financial statements
        ticker = yf.Ticker(tick)
        income_statement = ticker.financials.T[0:1]
        balance_sheet = ticker.balance_sheet.T[0:1]
        cash_flow = ticker.cashflow.T[0:1]

        # Add ticker symbol as a column
        for statement in (income_statement, balance_sheet, cash_flow):
            statement['Symbol'] = tick

        # Fetch the quarter date from the income_statement
        quarter = income_statement.index.values[0]
        
        # Reset index for each DataFrame and move 'Symbol' to front
        income_statement = move_symbol_to_front(income_statement.reset_index(drop=True))
        balance_sheet = move_symbol_to_front(balance_sheet.reset_index(drop=True))
        cash_flow = move_symbol_to_front(cash_flow.reset_index(drop=True))

        # Merge the financial statements into one row per ticker
        temp_merged = pd.merge(income_statement, balance_sheet, on='Symbol')
        full_merged = pd.merge(temp_merged, cash_flow, on='Symbol')
        full_merged['Quarter'] = quarter  # Add 'Quarter' after merging

        # Append the merged row to the main DataFrame
        all_financials = pd.concat([all_financials, full_merged], axis=0)

        # Collect individual statements if needed
        income_statements = pd.concat([income_statements, income_statement], axis=0)
        balance_sheets = pd.concat([balance_sheets, balance_sheet], axis=0)
        cash_flows = pd.concat([cash_flows, cash_flow], axis=0)

        print(f'Completed {tick}')
    except Exception as e:
        print(f"Failed to fetch data for {tick}: {e}")

# Merge the final DataFrame with the original S&P 500 companies list and reset index
all_financials = pd.merge(sp_500_companies, all_financials, on='Symbol')
all_financials.reset_index(drop=True, inplace=True)
cols = ['Quarter'] + [col for col in all_financials.columns if col != 'Quarter']
all_financials = all_financials[cols]
# Out:
# Completed MMM
# Completed AOS
# Completed ABT
# Completed ABBV
# Completed ACN
# Completed ADBE
# Completed AMD
# Completed AES
# Completed AFL
# Completed A
# Completed APD
# Completed ABNB
# Completed AKAM
# Completed ALB
# Completed ARE
# Completed ALGN
# Completed ALLE
# Completed LNT
# Completed ALL
# Completed GOOGL
# Completed GOOG
# Completed MO
# Completed AMZN
# Completed AMCR
# Completed AMTM
# Completed AEE
# Completed AEP
# Completed AXP
# Completed AIG
# Completed AMT
# Completed AWK
# Completed AMP
# Completed AME
# Completed AMGN
# Completed APH
# Completed ADI
# Completed ANSS
# Completed AON
# Completed APA
# Completed AAPL
# Completed AMAT
# Completed APTV
# Completed ACGL
# Completed ADM
# Completed ANET
# Completed AJG
# Completed AIZ
# Completed T
# Completed ATO
# Completed ADSK
# Completed ADP
# Completed AZO
# Completed AVB
# Completed AVY
# Completed AXON
# Completed BKR
# Completed BALL
# Completed BAC
# Completed BAX
# Completed BDX
# Failed to fetch data for BRK.B: index 0 is out of bounds for axis 0 with size 0
# Completed BBY
# Completed TECH
# Completed BIIB
# Completed BLK
# Completed BX
# Completed BK
# Completed BA
# Completed BKNG
# Completed BWA
# Completed BSX
# Completed BMY
# Completed AVGO
# Completed BR
# Completed BRO
# Failed to fetch data for BF.B: index 0 is out of bounds for axis 0 with size 0
# Completed BLDR
# Completed BG
# Completed BXP
# Completed CHRW
# Completed CDNS
# Completed CZR
# Completed CPT
# Completed CPB
# Completed COF
# Completed CAH
# Completed KMX
# Completed CCL
# Completed CARR
# Completed CTLT
# Completed CAT
# Completed CBOE
# Completed CBRE
# Completed CDW
# Completed CE
# Completed COR
# Completed CNC
# Completed CNP
# Completed CF
# Completed CRL
# Completed SCHW
# Completed CHTR
# Completed CVX
# Completed CMG
# Completed CB
# Completed CHD
# Completed CI
# Completed CINF
# Completed CTAS
# Completed CSCO
# Completed C
# Completed CFG
# Completed CLX
# Completed CME
# Completed CMS
# Completed KO
# Completed CTSH
# Completed CL
# Completed CMCSA
# Completed CAG
# Completed COP
# Completed ED
# Completed STZ
# Completed CEG
# Completed COO
# Completed CPRT
# Completed GLW
# Completed CPAY
# Completed CTVA
# Completed CSGP
# Completed COST
# Completed CTRA
# Completed CRWD
# Completed CCI
# Completed CSX
# Completed CMI
# Completed CVS
# Completed DHR
# Completed DRI
# Completed DVA
# Completed DAY
# Completed DECK
# Completed DE
# Completed DELL
# Completed DAL
# Completed DVN
# Completed DXCM
# Completed FANG
# Completed DLR
# Completed DFS
# Completed DG
# Completed DLTR
# Completed D
# Completed DPZ
# Completed DOV
# Completed DOW
# Completed DHI
# Completed DTE
# Completed DUK
# Completed DD
# Completed EMN
# Completed ETN
# Completed EBAY
# Completed ECL
# Completed EIX
# Completed EW
# Completed EA
# Completed ELV
# Completed EMR
# Completed ENPH
# Completed ETR
# Completed EOG
# Completed EPAM
# Completed EQT
# Completed EFX
# Completed EQIX
# Completed EQR
# Completed ERIE
# Completed ESS
# Completed EL
# Completed EG
# Completed EVRG
# Completed ES
# Completed EXC
# Completed EXPE
# Completed EXPD
# Completed EXR
# Completed XOM
# Completed FFIV
# Completed FDS
# Completed FICO
# Completed FAST
# Completed FRT
# Completed FDX
# Completed FIS
# Completed FITB
# Completed FSLR
# Completed FE
# Completed FI
# Completed FMC
# Completed F
# Completed FTNT
# Completed FTV
# Completed FOXA
# Completed FOX
# Completed BEN
# Completed FCX
# Completed GRMN
# Completed IT
# Completed GE
# Completed GEHC
# Completed GEV
# Completed GEN
# Completed GNRC
# Completed GD
# Completed GIS
# Completed GM
# Completed GPC
# Completed GILD
# Completed GPN
# Completed GL
# Completed GDDY
# Completed GS
# Completed HAL
# Completed HIG
# Completed HAS
# Completed HCA
# Completed DOC
# Completed HSIC
# Completed HSY
# Completed HES
# Completed HPE
# Completed HLT
# Completed HOLX
# Completed HD
# Completed HON
# Completed HRL
# Completed HST
# Completed HWM
# Completed HPQ
# Completed HUBB
# Completed HUM
# Completed HBAN
# Completed HII
# Completed IBM
# Completed IEX
# Completed IDXX
# Completed ITW
# Completed INCY
# Completed IR
# Completed PODD
# Completed INTC
# Completed ICE
# Completed IFF
# Completed IP
# Completed IPG
# Completed INTU
# Completed ISRG
# Completed IVZ
# Completed INVH
# Completed IQV
# Completed IRM
# Completed JBHT
# Completed JBL
# Completed JKHY
# Completed J
# Completed JNJ
# Completed JCI
# Completed JPM
# Completed JNPR
# Completed K
# Completed KVUE
# Completed KDP
# Completed KEY
# Completed KEYS
# Completed KMB
# Completed KIM
# Completed KMI
# Completed KKR
# Completed KLAC
# Completed KHC
# Completed KR
# Completed LHX
# Completed LH
# Completed LRCX
# Completed LW
# Completed LVS
# Completed LDOS
# Completed LEN
# Completed LLY
# Completed LIN
# Completed LYV
# Completed LKQ
# Completed LMT
# Completed L
# Completed LOW
# Completed LULU
# Completed LYB
# Completed MTB
# Completed MRO
# Completed MPC
# Completed MKTX
# Completed MAR
# Completed MMC
# Completed MLM
# Completed MAS
# Completed MA
# Completed MTCH
# Completed MKC
# Completed MCD
# Completed MCK
# Completed MDT
# Completed MRK
# Completed META
# Completed MET
# Completed MTD
# Completed MGM
# Completed MCHP
# Completed MU
# Completed MSFT
# Completed MAA
# Completed MRNA
# Completed MHK
# Completed MOH
# Completed TAP
# Completed MDLZ
# Completed MPWR
# Completed MNST
# Completed MCO
# Completed MS
# Completed MOS
# Completed MSI
# Completed MSCI
# Completed NDAQ
# Completed NTAP
# Completed NFLX
# Completed NEM
# Completed NWSA
# Completed NWS
# Completed NEE
# Completed NKE
# Completed NI
# Completed NDSN
# Completed NSC
# Completed NTRS
# Completed NOC
# Completed NCLH
# Completed NRG
# Completed NUE
# Completed NVDA
# Completed NVR
# Completed NXPI
# Completed ORLY
# Completed OXY
# Completed ODFL
# Completed OMC
# Completed ON
# Completed OKE
# Completed ORCL
# Completed OTIS
# Completed PCAR
# Completed PKG
# Completed PLTR
# Completed PANW
# Completed PARA
# Completed PH
# Completed PAYX
# Completed PAYC
# Completed PYPL
# Completed PNR
# Completed PEP
# Completed PFE
# Completed PCG
# Completed PM
# Completed PSX
# Completed PNW
# Completed PNC
# Completed POOL
# Completed PPG
# Completed PPL
# Completed PFG
# Completed PG
# Completed PGR
# Completed PLD
# Completed PRU
# Completed PEG
# Completed PTC
# Completed PSA
# Completed PHM
# Completed QRVO
# Completed PWR
# Completed QCOM
# Completed DGX
# Completed RL
# Completed RJF
# Completed RTX
# Completed O
# Completed REG
# Completed REGN
# Completed RF
# Completed RSG
# Completed RMD
# Completed RVTY
# Completed ROK
# Completed ROL
# Completed ROP
# Completed ROST
# Completed RCL
# Completed SPGI
# Completed CRM
# Completed SBAC
# Completed SLB
# Completed STX
# Completed SRE
# Completed NOW
# Completed SHW
# Completed SPG
# Completed SWKS
# Completed SJM
# Completed SW
# Completed SNA
# Completed SOLV
# Completed SO
# Completed LUV
# Completed SWK
# Completed SBUX
# Completed STT
# Completed STLD
# Completed STE
# Completed SYK
# Completed SMCI
# Completed SYF
# Completed SNPS
# Completed SYY
# Completed TMUS
# Completed TROW
# Completed TTWO
# Completed TPR
# Completed TRGP
# Completed TGT
# Completed TEL
# Completed TDY
# Completed TFX
# Completed TER
# Completed TSLA
# Completed TXN
# Completed TXT
# Completed TMO
# Completed TJX
# Completed TSCO
# Completed TT
# Completed TDG
# Completed TRV
# Completed TRMB
# Completed TFC
# Completed TYL
# Completed TSN
# Completed USB
# Completed UBER
# Completed UDR
# Completed ULTA
# Completed UNP
# Completed UAL
# Completed UPS
# Completed URI
# Completed UNH
# Completed UHS
# Completed VLO
# Completed VTR
# Completed VLTO
# Completed VRSN
# Completed VRSK
# Completed VZ
# Completed VRTX
# Completed VTRS
# Completed VICI
# Completed V
# Completed VST
# Completed VMC
# Completed WRB
# Completed GWW
# Completed WAB
# Completed WBA
# Completed WMT
# Completed DIS
# Completed WBD
# Completed WM
# Completed WAT
# Completed WEC
# Completed WFC
# Completed WELL
# Completed WST
# Completed WDC
# Completed WY
# Completed WMB
# Completed WTW
# Completed WYNN
# Completed XEL
# Completed XYL
# Completed YUM
# Completed ZBRA
# Completed ZBH
# Completed ZTS

# %% [markdown]
# ## Load / Save Financial Data to Use Later

# %%
# Optionally, save to CSV
all_financials.to_csv('./data/sp500_all_financials.csv', index=False)
sp_500_companies.to_csv('./data/sp500_companies.csv', index=False)
income_statements.to_csv('./data/sp500_income_statements.csv', index=False)
balance_sheets.to_csv('./data/sp500_balance_sheets.csv', index=False)
cash_flows.to_csv('./data/sp500_cash_flows.csv', index=False)
print("Data saved to CSV files.")

# Use a Pandas Excel writer using XlsxWriter as the engine
with pd.ExcelWriter('./data/sp500_financials.xlsx', engine='xlsxwriter') as writer:
    sp_500_companies.to_excel(writer, sheet_name='S&P 500 Companies', index=False)
    income_statements.to_excel(writer, sheet_name='Income Statements', index=False)
    balance_sheets.to_excel(writer, sheet_name='Balance Sheets', index=False)
    cash_flows.to_excel(writer, sheet_name='Cash Flows', index=False)

print("Data saved to Excel file with multiple sheets.")
# Out:
# Data saved to CSV files.
# Data saved to Excel file with multiple sheets.

# %% [markdown]
# ## Display the Financial Data in DataFrames

# %%
# Display sections of the DataFrames
print("All Financials:\n", all_financials.head(2))
print("S&P 500 Companies:\n", sp_500_companies.head(2))
print("Income Statements:\n", income_statements.head(2))
print("Balance Sheets:\n", balance_sheets.head(2))
print("Cash Flows:\n", cash_flows.head(2))
# Out:
# All Financials:
#       Quarter Symbol     Security  GICS Sector         GICS Sub-Industry  \
# 0 2023-12-31    MMM           3M  Industrials  Industrial Conglomerates
# 1 2023-12-31    AOS  A. O. Smith  Industrials         Building Products
#
#    Headquarters Location  Date added    CIK Founded  \
# 0  Saint Paul, Minnesota  1957-03-04  66740    1902
# 1   Milwaukee, Wisconsin  2017-07-26  91142    1916
#
#   Tax Effect Of Unusual Items  ... Net Income Extraordinary  \
# 0                  10008000.0  ...                      NaN
# 1                  -4530800.0  ...                      NaN
#
#   Cash Flowsfromusedin Operating Activities Direct Classesof Cash Payments  \
# 0                                              NaN                     NaN
# 1                                              NaN                     NaN
#
#   Other Cash Paymentsfrom Operating Activities Paymentson Behalfof Employees  \
# 0                                          NaN                           NaN
# 1                                          NaN                           NaN
#
#   Classesof Cash Receiptsfrom Operating Activities  \
# 0                                              NaN
# 1                                              NaN
#
#   Other Cash Receiptsfrom Operating Activities Securities Amortization  \
# 0                                          NaN                     NaN
# 1                                          NaN                     NaN
#
#   Restricted Common Stock Interest Paid Cfo
# 0                     NaN               NaN
# 1                     NaN               NaN
#
# [2 rows x 343 columns]
# S&P 500 Companies:
#    Symbol     Security  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
#
#    Headquarters Location  Date added    CIK Founded
# 0  Saint Paul, Minnesota  1957-03-04  66740    1902
# 1   Milwaukee, Wisconsin  2017-07-26  91142    1916
# Income Statements:
#    Symbol Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 0    MMM                  10008000.0              0.278     -6795000000.0
# 0    AOS                  -4530800.0              0.241       842600000.0
#
#   Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 0          36000000.0                             36000000.0
# 0         -18800000.0                            -18800000.0
#
#   Net Income From Continuing Operation Net Minority Interest  \
# 0                                      -6995000000.0
# 0                                        556600000.0
#
#   Reconciled Depreciation Reconciled Cost Of Revenue        EBITDA  ...  \
# 0            1987000000.0              18477000000.0 -6759000000.0  ...
# 0              78300000.0               2368000000.0   823800000.0  ...
#
#   Professional Expense And Contract Services Expense  \
# 0                                                NaN
# 0                                                NaN
#
#   Other Non Interest Expense Total Other Finance Cost  \
# 0                        NaN                      NaN
# 0                        NaN                      NaN
#
#   Rent Expense Supplemental Rent And Landing Fees Insurance And Claims  \
# 0                       NaN                   NaN                  NaN
# 0                       NaN                   NaN                  NaN
#
#   Depletion Income Statement Net Income From Tax Loss Carryforward  \
# 0                        NaN                                   NaN
# 0                        NaN                                   NaN
#
#   Net Income Extraordinary Securities Amortization
# 0                      NaN                     NaN
# 0                      NaN                     NaN
#
# [2 rows x 85 columns]
# Balance Sheets:
#    Symbol Treasury Shares Number Ordinary Shares Number Share Issued  \
# 0    MMM            391451920.0            552581136.0  944033056.0
# 0    AOS             43180265.0            147527327.0  190577212.0
#
#         Net Debt     Total Debt Tangible Book Value Invested Capital  \
# 0  10102000000.0  16854000000.0      -12346000000.0    20842000000.0
# 0            NaN    155200000.0         874300000.0     1971700000.0
#
#   Working Capital Net Tangible Assets  ... Other Inventories  \
# 0    1082000000.0      -12346000000.0  ...               NaN
# 0     555000000.0         874300000.0  ...               NaN
#
#   Held To Maturity Securities Cash Cash Equivalents And Federal Funds Sold  \
# 0                         NaN                                          NaN
# 0                         NaN                                          NaN
#
#   Trading Securities  \
# 0                NaN
# 0                NaN
#
#   Financial Assets Designatedas Fair Value Through Profitor Loss Total  \
# 0                                                NaN
# 0                                                NaN
#
#   Dueto Related Parties Non Current Investmentsin Subsidiariesat Cost  \
# 0                               NaN                               NaN
# 0                               NaN                               NaN
#
#   Current Deferred Taxes Assets Accrued Interest Receivable  \
# 0                           NaN                         NaN
# 0                           NaN                         NaN
#
#   Restricted Common Stock
# 0                     NaN
# 0                     NaN
#
# [2 rows x 141 columns]
# Cash Flows:
#    Symbol Free Cash Flow Repurchase Of Capital Stock Repayment Of Debt  \
# 0    MMM   5065000000.0                 -33000000.0     -3086000000.0
# 0    AOS    597700000.0                -306500000.0               NaN
#
#   Issuance Of Debt Issuance Of Capital Stock Capital Expenditure  \
# 0     2835000000.0                       NaN       -1615000000.0
# 0              NaN                       NaN         -72600000.0
#
#   Interest Paid Supplemental Data Income Tax Paid Supplemental Data  \
# 0                     520000000.0                      1384000000.0
# 0                             NaN                               NaN
#
#   End Cash Position  ... Dividend Paid Cfo Depletion Taxes Refund Paid  \
# 0      5933000000.0  ...               NaN       NaN               NaN
# 0       339900000.0  ...               NaN       NaN               NaN
#
#   Cash Flowsfromusedin Operating Activities Direct Classesof Cash Payments  \
# 0                                              NaN                     NaN
# 0                                              NaN                     NaN
#
#   Other Cash Paymentsfrom Operating Activities Paymentson Behalfof Employees  \
# 0                                          NaN                           NaN
# 0                                          NaN                           NaN
#
#   Classesof Cash Receiptsfrom Operating Activities  \
# 0                                              NaN
# 0                                              NaN
#
#   Other Cash Receiptsfrom Operating Activities Interest Paid Cfo
# 0                                          NaN               NaN
# 0                                          NaN               NaN
#
# [2 rows x 111 columns]
